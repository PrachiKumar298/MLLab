# %% [markdown]
# <a href="https://colab.research.google.com/github/PrachiKumar298/MLLab/blob/main/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
print("Google Drive mounted successfully!")
# Out:
# Mounted at /content/drive
# Google Drive mounted successfully!

# %%
import pandas as pd
import numpy as np
file_path = '/content/drive/My Drive/Iris.csv'
df= pd.read_csv(file_path)

print(df.head())
print('-----------------------------------------------------------')

print(df.info())
print('-----------------------------------------------------------')

print(df.columns)
print('-----------------------------------------------------------')

print(df.shape)
print('-----------------------------------------------------------')

print(df.dtypes)
print('-----------------------------------------------------------')

print(df.info)
print('-----------------------------------------------------------')

sept_len=df['SepalLengthCm']
print(sept_len.head())
print('-----------------------------------------------------------')

print(df.tail())
print('-----------------------------------------------------------')

subset=df[['SepalLengthCm', 'SepalWidthCm', 'Species']]
print(subset.head())
print('-----------------------------------------------------------')

print(df.loc[0])
print(df.loc[[0,99,149]])
print('-----------------------------------------------------------')

print(df.iloc[1])
print(df.iloc[-1])
print('-----------------------------------------------------------')

print(df.loc[:,['SepalLengthCm', 'SepalWidthCm', 'Species']])
print('-----------------------------------------------------------')

subset=df.iloc[:,[0,1,2,3,4]]
print(subset.head())
print('-----------------------------------------------------------')

range1=list(range(6))
subset=df.iloc[:,range1]
print(df.loc[99,'SepalLengthCm'])
print('-----------------------------------------------------------')

print(df.iloc[[0,99,149],[0,3,5]])
print('-----------------------------------------------------------')

print(df.isnull().count())
print('-----------------------------------------------------------')

print(df.notnull().sum)
print('-----------------------------------------------------------')

df.loc[10:15,"SepalLengthCm"]=np.nan
df.loc[20:25,"SeaplWidthCm"]=np.nan
print(df.isnull().count())
print(df.notnull().sum())
print('-----------------------------------------------------------')

df["SepalLengthCm"].fillna(df["SepalLengthCm"].mean(),inplace=True)
df["SepalWidthCm"].fillna(df["SepalWidthCm"].median(),inplace=True)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# -----------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
# ...
